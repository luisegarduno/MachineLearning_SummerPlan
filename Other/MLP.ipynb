# %%
import sys
import numpy as np
import pandas as pd
from scipy.special import expit
from sklearn.metrics import accuracy_score

# %%
# MultiLayerPerceptron
class MLP(object):
    def __init__(self,
                 n_hidden=30,
                 C=0.0,
                 epochs=500,
                 eta=0.001,
                 random_state=None,
                 alpha=0.0,
                 decrease_const=0.0,
                 shuffle=True,
                 minibatches=1,
                 activation='sigmoid',
                 obj_function='quadriatic'):
        """
        :param n_hidden: n hidden layers 
        :param C: a value
        :param epochs: number of epochs
        :param eta: (eta) Step Size
        :param random_state: boolean value
        :param alpha: alpha value
        :param decrease_const: decrease constant
        :param shuffle: shuffle flag
        :param minibatches: number of mini-batches
        :param activation: activation function
        :param obj_function: The function we want to min/max
        """
        np.random.seed(random_state)
        
        self.n_hidden = n_hidden
        self.l2_C = C
        self.epochs = epochs
        self.eta = eta
        self.alpha = alpha
        self.decrease_const = decrease_const
        self.shuffle = shuffle
        self.minibatches = minibatches
        self.activation = activation
        self.obj_function = obj_function
        
    
    def set_parameters(self):
        """
        Set Parameters
        
        :return: 
        """
    
    def get_parameters(self):
        """
        Get Parameters
        
        :return: 
        """
        
    def get_gradient(self):
        """
        Get Gradient
        
        :return: 
        """
    
    def encode_labels(self):
        """
        Encode Labels
        
        :return: 
        """
    
    def initialize_weights(self):
        """
        Initialize Weights
        
        :return: 
        """
        
    def activation(self):
        """
        Activation Function
        
        :return: 
        """
        
    def add_bias_unit(self):
        """
        Add bias unit
        
        :return: 
        """
    
    def l2_reg(self):
        """
        L2 Regularization
        
        :return: 
        """
    
    def cost(self):
        """
        Cost
        
        :return: 
        """
    
    def feed_forward(self):
        """
        Feed Forward Layer
        
        :return: 
        """
    
    def fit(self):
        """
        fit - perform a step of a training process
        
        :return: 
        """
        
    def predict(self):
        """
        Predict Probability
        
        :return: 
        """
